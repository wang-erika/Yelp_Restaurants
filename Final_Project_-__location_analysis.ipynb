# %%
import pandas as pd
import numpy as np
import json
business_df = pd.read_json('yelp_academic_dataset_business.json', lines=True)
print(len(business_df.index))
business_df.dropna()
print(len(business_df.index))
business_df.head()
# Out:
# 150346
# 150346
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# ...

# %%
review_1_df = pd.read_json('yelp_review_part_1.json', lines=True)
print(len(review_df.index))
review_1_df.dropna()
print(len(review_df.index))
review_1_df.head()
# Out:
# 147582
# 147582
#                 review_id                 user_id             business_id  \
# 0  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 1  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 2  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 3  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 4  6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      4       1      0     1
# 3      1       1      2     1
# 4      5       0      2     0
#
#                                                 text                date
# 0  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 1  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 2  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# ...

# %%
review_2_df = pd.read_json('yelp_review_part_2.json', lines=True)

print(len(review_df.index))
review_2_df.dropna()
print(len(review_df.index))
review_2_df.head()
# Out:
# 147582
# 147582
#                 review_id                 user_id             business_id  \
# 0  R3ImolC9IWqdpvwQ3NIzWw  F9HH9Iuqz_-hsaA_oOavcw  s9qB7VvbbSNTp3u8InMG0w
# 1  VSZ1HOc_jdK6rXfNlzMYlw  E7xs2VjwD1kkRnvRI-_kcQ  fEdDmhp6MQhuPF-iVLcmEw
# 2  RzoEGX986J6oVE1zjGu5rw  Tvegk5s428x5XwFZcTQypg  d_tRshM-w6S4QxE4VVi8tQ
# 3  MOQI9b51mSNpNjAN709gqw  8VNmuYmFboXleIFf-stnFg  plobBsTtVUODb353xxFT_g
# 4  j3qHwrqluh0HYK6QkaoytA  A7jYGjSnS-eur6W0_W9aYw  dJfkfBbJz7wi0RgW-ph_Eg
#
#    stars  useful  funny  cool  \
# 0      5       0      0     0
# 1      3       0      1     1
# 2      3       9      6     6
# 3      4       2      0     0
# 4      4       0      0     1
#
#                                                 text                date
# 0  Conveniently located! Zeti was extremely helpf... 2017-01-04 16:48:26
# 1  its your average Mexican restaurant. Although ... 2014-03-16 19:03:11
# 2  Jone's menu alone made me happy :) What do you... 2010-01-19 05:59:50
# ...

# %%
frames = [review_1_df, review_2_df]

review_df = pd.concat(frames)

review_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 1  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 2  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 3  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 4  6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      4       1      0     1
# 3      1       1      2     1
# 4      5       0      2     0
#
#                                                 text                date
# 0  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 1  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 2  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# ...

# %%
csv_review_name = "yelp_reviews.csv"
csv_business_name = "yelp_business.csv"
review_df.to_csv(csv_review_name, index=False)
business_df.to_csv(csv_business_name, index=False)

# %%
df = pd.read_csv('yelp_reviews.csv')
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 1  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 2  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 3  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 4  6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      4       1      0     1
# 3      1       1      2     1
# 4      5       0      2     0
#
#                                                 text                 date
# 0  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 1  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 2  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# ...

# %%
# chinese_df = business_df.filter(like='Chinese', axis=0)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# chinese_df = business_df[business_df['categories'].str.contains("Chinese", na=False)]
# chinese_df = chinese_df.groupby('city').mean()
# chinese_df = chinese_df.filter(items=['city', 'stars'])

# print(chinese_df)

thai_df = business_df[business_df['categories'].str.contains("Thai", na=False)]
thai_df = thai_df.groupby('city').mean()
thai_df = thai_df.filter(items=['city', 'stars'])

print(thai_df)

# italian_df = business_df[business_df['categories'].str.contains("Italian", na=False)]
# italian_df = italian_df.groupby('city').mean()
# italian_df = italian_df.filter(items=['city', 'stars'])

# print(italian_df)

# mexican_df = business_df[business_df['categories'].str.contains("Mexican", na=False)]
# mexican_df = mexican_df.groupby('city').mean()
# mexican_df = mexican_df.filter(items=['city','state','stars'])

# print(mexican_df)


# indian_df = business_df[business_df['categories'].str.contains("Indian", na=False)]
# indian_df = indian_df.groupby('city').mean()
# indian_df = indian_df.filter(items=['city', 'stars'])

# print(indian_df)

# business_df = business_df.groupby('city').mean()
# grouped_df.filter(items=['city', 'stars'])
# # df.loc[df[‘Color’] == ‘Green’]
# grouped_df.loc[grouped_df['city'] == "San Francisco"]
# Out:
#                           stars
# city
# Abington               3.812500
# Ambler                 3.875000
# Antioch                4.125000
# Ardmore                4.000000
# Arnold                 4.500000
# Avon                   4.250000
# Bala Cynwyd            3.750000
# Ballwin                3.666667
# Belleville             4.250000
# Bensalem               4.250000
# Berlin                 2.500000
# Berwyn                 3.166667
# Beverly                4.000000
# Blackwood              3.000000
# Blue Bell              4.000000
# Boise                  3.750000
# Boothwyn               4.500000
# Brandon                4.363636
# Brentwood              3.722222
# Bridgeton              3.500000
# Bristol                4.000000
# Brownsburg             4.500000
# Bryn Mawr              3.875000
# Buckingham             3.500000
# Carmel                 4.333333
# Carpinteria            4.500000
# Chadds Ford            3.000000
# Chalmette              4.000000
# ...
